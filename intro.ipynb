# %%
print("Hi, Belkacem!")
# Out:
# Hi, Belkacem!

# %% [markdown]
# This shows how to document
# the calculation below

# %%
1200000 * 220
# Out:
# 264000000

# %%
_ / 1e6
# Out:
# 264.0

# %% [markdown]
# # Heading1
# ## Heading2
# ### Heading3
# Hello!
# * Orange
# * Strawbwrry
# * Grappe
#
# **Bold this text**
#
# *Make this italic*
#
# http://www.edx.com

# %% [markdown]
# **Latex** equation:
#
# $\int_0^\infty x^{-\alpha}$

# %%
# %matplotlib inline
from matplotlib.pyplot import plot
plot([10, 0, 20, 0, 30, 0, 10, 0, 20, 0, 30])

# %% [markdown]
# This is an example of using matplotlib.
# You need to install matplotlib with
# pip install matplotlib
# if running jupyter lab from virtual environment
